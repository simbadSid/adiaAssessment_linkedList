# %%
from matplotlib import pyplot as plt
import math

plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True


SIZE                                                   = [1000000, 11000000, 21000000, 31000000, 41000000, 51000000, 61000000, 71000000, 81000000, 91000000][:7]

executionTime_0_orderRefactor_onlyForward              = [16, 186, 372, 584, 833, 1024, 1181, 1498, 2799, 2182][:7]
executionTime_0_orderRefactor_onlyBackward             = [18, 199, 379, 573, 865, 1052, 1320, 1529, 1928, 3706][:7]
executionTime_0_orderRefactor_halfForwardHalfBackward  = [19, 222, 416, 607, 889, 1166, 1563, 1769, 2253, 3763][:7]
executionTime_0_orderRefactor_randomForwardBackward    = [27, 268, 467, 702, 1059, 1316, 1779, 2087, 2670, 5302][:7]

executionTime_1_twoPointersInOne_onlyForward            = [21, 224, 431, 696, 936, 1211, 1403, 1682, 2684, 5913][:7]
executionTime_1_twoPointersInOne_onlyBackward           = [22, 247, 455, 700, 946, 1166, 1456, 2305, 3430, 6166][:7]
executionTime_1_twoPointersInOne_halfForwardHalfBackward= [25, 241, 439, 689, 939, 1149, 1447, 1823, 2367, 3412][:7]
executionTime_1_twoPointersInOne_randomForwardBackward  = [26, 236, 435, 714, 918, 1175, 1408, 1995, 3691, 3959][:7]

#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_0_orderRefactor_onlyForward,            label="0_orderRefactor_onlyForward",            color="green",  marker="o")
plt.plot(SIZE, executionTime_0_orderRefactor_onlyBackward,           label="0_orderRefactor_onlyBackward",           color="blue",   marker="o")
plt.plot(SIZE, executionTime_0_orderRefactor_halfForwardHalfBackward,label="0_orderRefactor_halfForwardHalfBackward",color="red",  marker="o")
plt.plot(SIZE, executionTime_0_orderRefactor_randomForwardBackward,  label="0_orderRefactor_randomForwardBackward",  color="purple", marker="o")

plt.plot(SIZE, [0.00001*i*2 for i in SIZE], ' ', label="a*N*2 (a=10^-5)",    color="black", marker="+", markersize=20)

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: implementation 0_orderRefactor')
plt.legend(loc='upper left')
plt.savefig('benchmark_0_orderRefactor.png', facecolor='w')


#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_1_twoPointersInOne_onlyForward,            label="1_twoPointersInOne_onlyForward",            color="green",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_onlyBackward,           label="1_twoPointersInOne_onlyBackward",           color="blue",   marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_halfForwardHalfBackward,label="1_twoPointersInOne_halfForwardHalfBackward",color="red",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_randomForwardBackward,  label="1_twoPointersInOne_randomForwardBackward",  color="purple", marker="o")

plt.plot(SIZE, [0.00001*i*2 for i in SIZE], ' ', label="a*N*2 (a=10^-5)", color="black", marker="+", markersize=20)

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: implementation 1_twoPointersInOn')
plt.legend(loc='upper left')
plt.savefig('benchmark_1_twoPointersInOne.png', facecolor='w')


#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_0_orderRefactor_onlyForward,   label="0_orderRefactor_onlyForward",  color="green",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_onlyForward, label="1_twoPointersInOne_onlyForward",color="red",  marker="o")

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: scenario onlyForward')
plt.legend(loc='upper left')
plt.savefig('benchmark_onlyForward.png', facecolor='w')


#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_0_orderRefactor_onlyBackward,   label="0_orderRefactor_onlyBackward",   color="green",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_onlyBackward, label="1_twoPointersInOne_onlyBackward", color="red",  marker="o")

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: scenario onlyBackward')
plt.legend(loc='upper left')
plt.savefig('benchmark_onlyBackward.png', facecolor='w')


#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_0_orderRefactor_halfForwardHalfBackward,  label="0_orderRefactor_halfForwardHalfBackward",  color="green",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_halfForwardHalfBackward,label="1_twoPointersInOne_halfForwardHalfBackward",color="red",  marker="o")

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: scenario halfForwardHalfBackward')
plt.legend(loc='upper left')
plt.savefig('benchmark_halfForwardHalfBackward.png', facecolor='w')


#################################
fig = plt.figure()
plt.grid()

plt.plot(SIZE, executionTime_0_orderRefactor_randomForwardBackward,  label="0_orderRefactor_randomForwardBackward",  color="green",  marker="o")
plt.plot(SIZE, executionTime_1_twoPointersInOne_randomForwardBackward,label="1_twoPointersInOne_randomForwardBackward",color="red",  marker="o")

plt.xlabel('List size')
plt.ylabel('Total execution time (ms)')
plt.title('Execution time benchmark: scenario randomForwardBackward')
plt.legend(loc='upper left')
plt.savefig('benchmark_randomForwardBackward.png', facecolor='w')







plt.show()
